# %%
import os, sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
import csv

data = {
    'Method': [],
    'Sessions': [],
    'PixCorr': [],
    'SSIM': [],
    'AlexNet(2)': [],
    'AlexNet(5)': [],
    'InceptionV3': [],
    'CLIP': [],
    'EffNet-B': [],
    'SwAV': [],
    'FwdRetrieval': [],
    'BwdRetrieval': [],
    'Brain Corr. nsd_general': [],
    'Brain Corr. V1': [],
    'Brain Corr. V2': [],
    'Brain Corr. V3': [],
    'Brain Corr. V4': [],
    'Brain Corr. higher_vis': []}

df = pd.DataFrame(data)
files = ["brain_diffuser_125_trials_subj01.csv", "brain_diffuser_375_trials_subj01.csv", "brain_diffuser_750_trials_subj01.csv", "brain_diffuser_1500_trials_subj01.csv", "brain_diffuser_2250_trials_subj01.csv", "brain_diffuser_3750_trials_subj01.csv", "brain_diffuser_7500_trials_subj01.csv", "brain_diffuser_15000_trials_subj01.csv", "brain_diffuser_27750_trials_subj01.csv", "brain_diffuser_30000_trials_subj01.csv",
         "takagi_decoded_text_01_subj01.csv", "takagi_decoded_text_05_subj01.csv", "takagi_decoded_text_1_subj01.csv", "takagi_decoded_text_2_subj01.csv", "takagi_decoded_text_3_subj01.csv", "takagi_decoded_text_5_subj01.csv", "takagi_decoded_text_10_subj01.csv", "takagi_decoded_text_20_subj01.csv", "takagi_decoded_text_37_subj01.csv", "takagi_decoded_text_40_subj01.csv",
         "mindeye2_125_pt_subj01.csv", "mindeye2_375_pt_subj01.csv", "mindeye2_1_pt_subj01.csv", "mindeye2_2_pt_subj01.csv", "mindeye2_3_pt_subj01.csv", "mindeye2_5_pt_subj01.csv", "mindeye2_10_pt_subj01.csv", "mindeye2_20_pt_subj01.csv", "mindeye2_37_pt_subj01.csv", "mindeye2_40_pt_subj01.csv",
         "mindeye2_125_subj01.csv", "mindeye2_375_subj01.csv", "mindeye2_1_subj01.csv", "mindeye2_2_subj01.csv", "mindeye2_3_subj01.csv", "mindeye2_5_subj01.csv", "mindeye2_10_subj01.csv", "mindeye2_20_subj01.csv", "mindeye2_37_subj01.csv", "mindeye2_40_subj01.csv",
         "mindeye1_125_subj01.csv", "mindeye1_375_subj01.csv", "mindeye1_1_subj01.csv", "mindeye1_2_subj01.csv", "mindeye1_3_subj01.csv", "mindeye1_5_subj01.csv", "mindeye1_10_subj01.csv", "mindeye1_20_subj01.csv", "mindeye1_37_subj01.csv", "mindeye1_40_subj01.csv"]
methods = ["brain_diffuser", "brain_diffuser", "brain_diffuser", "brain_diffuser", "brain_diffuser", "brain_diffuser", "brain_diffuser", "brain_diffuser", "brain_diffuser", "brain_diffuser",
           "takai_decoded_text", "takai_decoded_text", "takai_decoded_text", "takai_decoded_text", "takai_decoded_text", "takai_decoded_text", "takai_decoded_text", "takai_decoded_text", "takai_decoded_text", "takai_decoded_text",
           "mindeye2_pt", "mindeye2_pt", "mindeye2_pt", "mindeye2_pt", "mindeye2_pt", "mindeye2_pt", "mindeye2_pt",  "mindeye2_pt", "mindeye2_pt", "mindeye2_pt", 
           "mindeye2", "mindeye2", "mindeye2", "mindeye2", "mindeye2", "mindeye2", "mindeye2", "mindeye2", "mindeye2", "mindeye2",
           "mindeye1", "mindeye1", "mindeye1", "mindeye1", "mindeye1", "mindeye1", "mindeye1", "mindeye1", "mindeye1", "mindeye1"]
sessions = [0.166, 0.5, 1, 2, 3, 5, 10, 20, 37, 40, 
            0.166, 0.5, 1, 2, 3, 5, 10, 20, 37, 40, 
            0.166, 0.5, 1, 2, 3, 5, 10, 20, 37, 40, 
            0.166, 0.5, 1, 2, 3, 5, 10, 20, 37, 40, 
            0.166, 0.5, 1, 2, 3, 5, 10, 20, 37, 40,]

for file, method, sessions in zip(files, methods, sessions):
    data_list = []
    with open(f'tables/{file}', 'r') as file:
        csv_reader = csv.reader(file)
        next(csv_reader)  # Skip the header row
        for row in csv_reader:
            row_values = [float(value) if value != "" else None for value in row]
            data_list.append(row_values)
    new_row_data = {
    'Method': method,
    'Sessions': sessions,
    'PixCorr': data_list[0],
    'SSIM': data_list[1],
    'AlexNet(2)': data_list[2],
    'AlexNet(5)': data_list[3],
    'InceptionV3': data_list[4],
    'CLIP': data_list[5],
    'EffNet-B': data_list[6],
    'SwAV': data_list[7],
    'FwdRetrieval': data_list[8],
    'BwdRetrieval': data_list[9],
    'Brain Corr. nsd_general': data_list[10],
    'Brain Corr. V1': data_list[11],
    'Brain Corr. V2': data_list[12],
    'Brain Corr. V3': data_list[13],
    'Brain Corr. V4': data_list[14],
    'Brain Corr. higher_vis': data_list[15]}
    df = pd.concat([df, pd.DataFrame(new_row_data)])
print(df)
df.to_csv('tables/output.csv', index=False)
# Out:
#                Method  Sessions   PixCorr      SSIM  AlexNet(2)  AlexNet(5)  \
# 0      brain_diffuser     0.166  0.135954  0.328090    0.745765    0.787594
# 0      brain_diffuser     0.500  0.193563  0.353911    0.841632    0.872075
# 0      brain_diffuser     1.000  0.221132  0.365859    0.882136    0.903035
# 0      brain_diffuser     2.000  0.244741  0.371465    0.915281    0.932323
# 0      brain_diffuser     3.000  0.265023  0.376177    0.930566    0.943794
# 0      brain_diffuser     5.000  0.290335  0.383721    0.944919    0.956289
# 0      brain_diffuser    10.000  0.318743  0.387730    0.962174    0.966365
# 0      brain_diffuser    20.000  0.328298  0.389301    0.970180    0.976402
# 0      brain_diffuser    37.000  0.331086  0.386292    0.970025    0.978142
# 0      brain_diffuser    40.000  0.328000  0.385529    0.972324    0.979611
# 0  takai_decoded_text     0.166  0.153153  0.381132    0.611846    0.622578
# ...

# %%
df['EffNet-B'] = 1 - df['EffNet-B']
df['SwAV'] = 1 - df['SwAV']
# print(mindeye1_rows)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

data = df
# Setting the plot style
sns.set(style="whitegrid")

# Getting the list of methods and metrics
methods = data['Method'].unique()
# metrics = data.columns[2:]

data['Sessions_str'] = data['Sessions'].astype(str)

# Creating a figure and a set of subplots
fig, ax = plt.subplots(figsize=(10, 8))
line_styles = [
    #  ('loosely dotted',        (0, (1, 10))),
     ('dotted',                (0, (1, 1))),
    #  ('densely dotted',        (0, (1, 1))),
     ('dashdotted',            (0, (3, 5, 1, 5))),
     ('loosely dashed',        (0, (5, 10))),
     ('dashed',                (0, (5, 5))),
     ('densely dashed',        (0, (5, 1))),
     ('long dash with offset', (5, (10, 3))),

     ('loosely dashdotted',    (0, (3, 10, 1, 10))),
     ('dashdotted',            (0, (3, 5, 1, 5))),
     ('densely dashdotted',    (0, (3, 1, 1, 1))),

     ('dashdotdotted',         (0, (3, 5, 1, 5, 1, 5))),
     ('loosely dashdotdotted', (0, (3, 10, 1, 10, 1, 10))),
     ('densely dashdotdotted', (0, (3, 1, 1, 1, 1, 1)))]
# selected_metrics = ['InceptionV3', 'CLIP', "EffNet-B", "SwAV"]
# selected_metrics = ["PixCorr", "SSIM", "AlexNet(2)", "AlexNet(5)"]
selected_metrics = ["Brain Corr. nsd_general", "Brain Corr. V1", "Brain Corr. V2", "Brain Corr. V3", "Brain Corr. V4", "Brain Corr. higher_vis"]
# selected_metrics = ["EffNet-B"]
bright_palette = sns.color_palette("bright", len(methods))
colors = ["deepskyblue", "lime", "red", "orange", "purple"]
# Normalizing the selected metrics
normalized_data = data.copy()
for metric in selected_metrics:
    normalized_data[metric] = (normalized_data[metric] - normalized_data[metric].min()) / (normalized_data[metric].max() - normalized_data[metric].min())

new_metric = normalized_data[selected_metrics].mean(axis=1)

# metric = 'Brain Corr. nsd_general'
for method_idx, method in enumerate(methods):
    method_data = normalized_data[normalized_data['Method'] == method]
    metric_average = method_data["Brain Corr. nsd_general"]#.mean(axis=1)
    sns.lineplot(x='Sessions_str', y=metric_average, data=method_data, ax=ax, 
                         color=colors[method_idx], #label=f"{method} - Normalized Average",
                         linestyle='-', linewidth=3)
    for metric_idx, metric in enumerate(selected_metrics[1:]):
        print(method, metric)
        sns.lineplot(x='Sessions_str', y=metric, data=method_data, ax=ax, 
                     color=colors[method_idx], #label=f"{method} - {metric}",
                     linestyle=line_styles[metric_idx][1], alpha=0.5)
    
# Enhancing the plot
# Setting meaningful x-ticks and y-ticks
# Setting custom x-ticks and y-ticks
# x_ticks = [0.166, 0.5, 1, 2, 20, 37, 40]
x_tick_labels = ["10 minutes", "30 minutes", "1 hour", "2 hours", "3 hours", "5 hours", "10 hours", "20 hours", "37 hours", "40 hours"]
ax.set_xticklabels(x_tick_labels, rotation=45, fontsize=18)

# Setting y-ticks
y_ticks = np.linspace(data[metric].min(), data[metric].max(), num=10)
ax.set_yticks(y_ticks)
ax.set_yticklabels([f"{tick:.2f}" for tick in y_ticks])

ax.set_xlabel('Number of Sessions', fontsize=22)
ax.set_ylabel('Normalized Metric Values', fontsize=22)
ax.set_title('Brain Correlation Scores of Reconstruction Methods Across Visual Cortex', fontsize=22)
# ax.set_title('Performance of Reconstruction Methods Across High Level Metrics', fontsize=25)
# ax.set_title('Performance of Reconstruction Methods Across Low Level Metrics', fontsize=25)
# ax.legend(title='Method and Metric', loc='upper left', bbox_to_anchor=(1, 1))
plt.yscale('linear')
plt.tight_layout()

#dummy lines with NO entries, just to create the black style legend
dummy_lines = []
for b_idx, b in enumerate(range(len(selected_metrics))):
    dummy_lines.append(ax.plot([],[], c="black", ls = line_styles[b_idx][1])[0])
dummy_lines.append(ax.plot([],[], c="black", ls = "-", linewidth=3)[0])
lines = ax.get_lines()
# [10, 15, 20, 0, 5]
# [14, 21, 28, 0, 7]
legend1 = plt.legend([lines[i] for i in [14, 21, 28, 0, 7]], ["MindEye2 Pretrained", "MindEye2 Not Pretrained", "MindEye1", "Brain Diffuser", "Takagi et al."], loc="lower right")
legend2 = plt.legend([dummy_lines[i] for i in range(0, len(selected_metrics) + 1)], selected_metrics, bbox_to_anchor=(1.0, 0.2), loc=4)
ax.add_artist(legend1)

plt.show()
# Out:
# brain_diffuser Brain Corr. nsd_general
# brain_diffuser Brain Corr. V1
# brain_diffuser Brain Corr. V2
# brain_diffuser Brain Corr. V3
# brain_diffuser Brain Corr. V4
# brain_diffuser Brain Corr. higher_vis
# takai_decoded_text Brain Corr. nsd_general
# takai_decoded_text Brain Corr. V1
# takai_decoded_text Brain Corr. V2
# takai_decoded_text Brain Corr. V3
# takai_decoded_text Brain Corr. V4
# takai_decoded_text Brain Corr. higher_vis
# mindeye2_pt Brain Corr. nsd_general
# mindeye2_pt Brain Corr. V1
# mindeye2_pt Brain Corr. V2
# mindeye2_pt Brain Corr. V3
# mindeye2_pt Brain Corr. V4
# mindeye2_pt Brain Corr. higher_vis
# mindeye2 Brain Corr. nsd_general
# mindeye2 Brain Corr. V1
# mindeye2 Brain Corr. V2
# mindeye2 Brain Corr. V3
# mindeye2 Brain Corr. V4
# mindeye2 Brain Corr. higher_vis
# mindeye1 Brain Corr. nsd_general
# mindeye1 Brain Corr. V1
# mindeye1 Brain Corr. V2
# mindeye1 Brain Corr. V3
# mindeye1 Brain Corr. V4
# mindeye1 Brain Corr. higher_vis
# ...
